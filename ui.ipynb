# %%
import pickle
import pymorphy3
import re
import tkinter as tk
from tkinter import Frame, Label, Button, Toplevel
import joblib

with open('ukrainian_stopwords.pkl', 'rb') as f:
    ukrainian_stopwords = pickle.load(f)

def preprocess(text):
    text = text.strip()
    text = re.sub(r'[^\w\s]', ' ', text) 
    text = text.lower()
    text = re.sub(r'\s+', ' ', text) 
    tokens = text.split()
    tokens = [word for word in tokens if len(word) > 1]
    tokens = [word for word in tokens if word not in ukrainian_stopwords]
    morph = pymorphy3.MorphAnalyzer(lang='uk')
    tokens = [morph.parse(word)[0].normal_form for word in tokens]
    tokens = [word for word in tokens if morph.parse(word)[0].tag.POS in {'NOUN', 'VERB', 'ADJ', 'ADV', 'ADJF'}]
    text = ' '.join(tokens)
    return text

with open('other/samples.txt', 'r') as file:
    content = file.read()

content = content.replace('"', '')
samples = [word.strip() for word in content.split('\n')]

reviews = []
l_s = len(samples)
for i in range(l_s):
    if i < 5:
        sent = "Негативний"
    elif i >= 5 and i < 10:
        sent = "Нейтральний"
    else: 
        sent = "Позитивний"
    reviews.append({"title": samples[i][:30]+'...', "content":samples[i], "sentiment":sent})
    


# Load the model and vectorizer
model = joblib.load("models/linear_svc.joblib")
vectorizer = joblib.load("models/vectorizer.joblib")

# Sentiment color mapping
sentiment_colors = {
    "Позитивний": "#4CAF50",  # Green
    "Нейтральний": "#FFC107",  # Amber
    "Негативний": "#F44336",  # Red
}

def analyze_text():
    """Analyze the sentiment of the input text."""
    text = text_input.get("1.0", "end-1c").strip()
    if not text:
        tk.messagebox.showwarning("Input Error", "Please enter some text for analysis.")
        return
    text_vectorized = vectorizer.transform([preprocess(text)])
    sentiment = model.predict(text_vectorized)[0]
    sentiment_map = {0: "Негативний", 1: "Нейтральний", 2: "Позитивний"}
    result_label.config(text=f"Настрій: {sentiment_map[sentiment]}")

def clear_text():
    """Clear the input text and result label."""
    text_input.delete("1.0", "end")
    result_label.config(text="")

def load_review():
    """Open the Load Review window and manage review selection."""
    def populate_review_list():
        """Populate the list with reviews."""
        for widget in review_list_frame.winfo_children():
            widget.destroy()  # Clear previous entries

        for idx, review in enumerate(reviews):
            # Create a frame for each review
            item_frame = Frame(review_list_frame, bg="white", padx=10, pady=5, relief="ridge", bd=1)
            item_frame.pack(fill="x", pady=5)

            def select_review(event, i=idx, frame=item_frame):
                """Handle review selection and styling."""
                nonlocal selected_review_idx
                if selected_review_idx != -1:  # Deselect the previous frame
                    previous_frame = review_list_frame.winfo_children()[selected_review_idx]
                    previous_frame.configure(bg="white")
                # Update the new selection
                selected_review_idx = i
                frame.configure(bg="#FFC0CB")  # Highlight the selected frame

            # Bind click event to select review
            item_frame.bind("<Button-1>", select_review)

            # Title
            title_label = Label(item_frame, text=review["title"], font=("Arial", 12, "bold"), bg="white", anchor="w")
            title_label.pack(side="left", expand=True, fill="x", padx=5)
            title_label.bind("<Button-1>", select_review)

            # Sentiment
            sentiment_label = Label(
                item_frame,
                text=review["sentiment"],
                font=("Arial", 12, "bold"),
                bg=sentiment_colors[review["sentiment"]],
                fg="white",
                padx=10,
                pady=5,
                relief="solid"
            )
            sentiment_label.pack(side="right", padx=5)
            sentiment_label.bind("<Button-1>", select_review)

    def load_selected_review():
        """Transfer selected review to the main window text field.""" 
        if selected_review_idx == -1:
            tk.messagebox.showwarning("Selection Error", "Please select a review to load.")
            return
        text_input.delete("1.0", "end")
        text_input.insert("1.0", reviews[selected_review_idx]["content"])
        review_window.destroy()

    def resize_canvas(event):
        """Adjust the canvas width to match the container frame."""
        canvas_width = event.width
        canvas.itemconfig(scrollable_window, width=canvas_width)

    # Initialize variables
    selected_review_idx = -1

    # Create the Load Window
    review_window = Toplevel(window)
    review_window.title("Приклади рев'ю")
    review_window.geometry("600x500")
    review_window.configure(bg="#f5f5f5")
    review_window.resizable(False, False)

    # Title
    title_label = Label(
        review_window, text="Оберіть рев'ю", font=("Arial", 14, "bold"), bg="#f5f5f5", fg="#333"
    )
    title_label.pack(pady=10)

    # Create a frame with scrollbar for reviews
    container_frame = Frame(review_window, bg="#f5f5f5")
    container_frame.pack(fill="both", expand=True, padx=10, pady=10)

    canvas = tk.Canvas(container_frame, bg="#f5f5f5", highlightthickness=0)
    scrollbar = tk.Scrollbar(container_frame, orient="vertical", command=canvas.yview)
    scrollable_frame = Frame(canvas, bg="#f5f5f5", padx=10)

    scrollable_window = canvas.create_window((0, 0), window=scrollable_frame, anchor="nw")

    # Bind resize event to dynamically adjust canvas width
    container_frame.bind("<Configure>", resize_canvas)

    scrollable_frame.bind(
        "<Configure>",
        lambda e: canvas.configure(scrollregion=canvas.bbox("all"))
    )

    canvas.configure(yscrollcommand=scrollbar.set)

    canvas.pack(side="left", fill="both", expand=True)
    scrollbar.pack(side="right", fill="y")

    review_list_frame = scrollable_frame

    # Populate initial reviews
    populate_review_list()

    # Load Button
    load_button = Button(
        review_window,
        text="Завантажити обране рев'ю",
        command=load_selected_review,
        font=("Arial", 12, "bold"),
        bg="#4CAF50",
        fg="white",
        activebackground="#45a049",
        relief="flat",
        padx=10,
        pady=5
    )
    load_button.pack(pady=10)

# Main Window Setup
window = tk.Tk()
window.title("Модуль сентиментального аналізу тексту")
window.geometry("550x520")
window.configure(bg="#f5f5f5")

# Title label
title_label = Label(window, text="Модуль сентиментального аналізу тексту", font=("Arial", 18, "bold"), bg="#f5f5f5", fg="#333")
title_label.pack(pady=10)

# Instruction label
instruction_label = Label(window, text="Введіть ваше рев'ю нижче:", font=("Arial", 12), bg="#f5f5f5", fg="#555")
instruction_label.pack()

# Text input field
text_input = tk.Text(window, height=14, width=50, font=("Arial", 12), bd=2, relief="solid", padx=10, pady=10)
text_input.pack(pady=10)

# Button row
button_frame = Frame(window, bg="#f5f5f5")
button_frame.pack(pady=10)


# Load Review button
load_button = Button(
    button_frame,
    text="Завантажити",
    command=load_review,
    font=("Arial", 12, "bold"),
    bg="#2196F3",
    fg="white",
    activebackground="#1E88E5",
    relief="flat",
    padx=10,
    pady=5
)
load_button.pack(side="left", padx=5)

# Analyze button
analyze_button = Button(
    button_frame,
    text="Аналізувати",
    command=analyze_text,
    font=("Arial", 12, "bold"),
    bg="#4CAF50",
    fg="white",
    activebackground="#45a049",
    relief="flat",
    padx=10,
    pady=5
)
analyze_button.pack(side="left", padx=5)

# Clear button
clear_button = Button(
    button_frame,
    text="Очистити",
    command=clear_text,
    font=("Arial", 12, "bold"),
    bg="#F44336",
    fg="white",
    activebackground="#E53935",
    relief="flat",
    padx=10,
    pady=5
)
clear_button.pack(side="left", padx=5)

# Result label
result_label = Label(window, text="", font=("Arial", 16, "bold"), bg="#f5f5f5", fg="#333", wraplength=450, justify="center")
result_label.pack(pady=12)

# Footer label
footer_label = Label(window, text="Зроблено Пархоменко Едуардом, всі права захищені", font=("Arial", 10, "italic"), bg="#f5f5f5", fg="#888")
footer_label.pack(side="bottom", pady=5)

# Run the application
window.mainloop()

# %%
def preprocess(text):
    text = text.strip()
    text = re.sub(r'[^\w\s]', ' ', text) 
    text = text.lower()
    text = re.sub(r'\s+', ' ', text) 
    tokens = text.split()
    tokens = [word for word in tokens if len(word) > 1]
    tokens = [word for word in tokens if word not in ukrainian_stopwords]
    morph = pymorphy3.MorphAnalyzer(lang='uk')
    tokens = [morph.parse(word)[0].normal_form for word in tokens]
    tokens = [word for word in tokens if morph.parse(word)[0].tag.POS in {'NOUN', 'VERB', 'ADJ', 'ADV', 'ADJF'}]
    text = ' '.join(tokens)
    return text

# %%
with open('other/samples.txt', 'r') as file:
    content = file.read()

content = content.replace('"', '')
samples = [word.strip() for word in content.split('\n')]
samples
# Out:
# ["'Я лише хочу, щоб для цієї індички був рейтинг нижче 1.Що я можу сказати: погане редагування (о, і вам не потрібно бути експертом, щоб зловити це), страшна акторська майстерність та діалог, смішні сцени боротьби, дурний розвиток персонажів і далі. Сігал, мабуть, не вистачає виплат аліментів чи щось, щоб скласти цей безлад і розпродаж його для глядачів.Більшість героїв дій стають кращими з досвідом, але найдавніші твори Seagal настільки перевершують це. Замість того, щоб бути напівпристойним персонажем, як військово-морська печатка, або оперативник ЦРУ чи поліцейського, він грає в археолога, який одягається, як він прослуховує, що він не є в Матриці або Джона Шафта.Виглядає абсолютно смішно на копаннях у пустелі Китаю.Вони намагаються пояснити заднім числом, де цей професор отримав свої вищі бойові навички кунг-фу, але це працює так само погано, як і їхня спроба пояснити, як засуджений отримує доктор з археології, перебуваючи у в\\'язниці (без будь-яких польових робіт, звичайно). Тоді є прості технічні аспекти фільму, як перебування в Болгарії, але всі ознаки є англійською мовою, а люди або китайські, або американські.Навіть деякі з китайських діалогу підзаголовок англійською мовою абсолютно неправильно. Тоді є акторська майстерність.По-перше, у фільмі є кілька найгірших псевдо-фен-шуй/азіатських/містицизму/філософських баблів Стівена Сігала/азіатського/філософського баблінгу, які можна було б собі уявити.Дурні метафори, які, мабуть, мають лише сенс для нього.Чой Кінг-Бе, як Вонг Дай, безумовно, неправильний хлопець, коли він відчайдушно намагається доставити кожен рядок як якийсь зловісний лиходій коміксів, а не китайський бізнесмен, який він є.Кори Джонсон настільки ж дурний, як агент ФБР, який не має жодної ролі, крім того, щоб блукати сценами та висловлювати лінії, що ображають католиків, китайців та французів.Я не зрозумів, як він і його партнер, здається, зможуть ходити по сходах за Сігал, невидимим для нього та язика майже до самого кінця. Це навіть не хороший бойовик для тих, хто насолоджувався Seagal як Кейсі Райбек.Сцени боротьби-це або тривале плескання пиріг, що ляпає з охресленою кісткою, що розтріскується на висоту німого з кунг-фу в перукарні в стилі мавпи в комплекті з усією смішною силою сили тяжіння, що протистоять трюкам, що пригнічується тигром. Я не можу уявити жодної аудиторії, крім рецензентів, для найгіршого фільму 2003 року, до якого сподобається цей фільм.',",
#  "'Цей поганий виправдання для фільму жахливий.Я мушу визнати, що це було так добре, що це погано, і високі рейтинги - це хороша форма сарказму.Але тепер це має зупинитися.Технічно невмілі мирські повідомлення, що годують ложкою, з художньою вагою комерційних, лицемірних, щонайменше, лицемірно, воно заслуговує на забуття.Містер Дерек, я сподіваюся, що ти зрозумієш, що ти такий дивний друг, який всі знають, що кульгавий, але з доброти та християнського обов\\'язку ставляться так, як він крутий чи щось.Це працює, якщо ви хороша пристойна людина, а не, якщо ви жахливий зарозумілий хуліган, як ви.Так, містер тато Дерек закінчиться в книгах історії Інтернету за те, що він є оманливим кислим старим, який вважає хорошим прикладом для дітей, але насправді має плакат Кім Чен Ун у своїй шафі.Знищіть цей фільм, якщо ви всі маєте совість, як я сподіваюсь, що Ihe та всі інші каналі YouTube, закриті Дереком, з злої знищить його в судах.',",
#  "'Що я можу сказати про цей фільм, про який інші ще не сказали?Кожен сказав, що це неймовірно погано, і це точний опис.Причини, які я насправді спостерігав за цим від початку до кінця, - це те, що він мене розвеселив, помилки безперервності, погана акторська майстерність і бог жахливо вмирають.Хтось повинен був навчити цим акторам та додатково, як вкладати трохи життя у свої вмираючі навички.Їх поганий вмирання змусив мене сміятися.Ще одна річ, перш ніж я підпишусь, і це більше поради для режисерів, не мають фактичних робочих годин у кадрі, у будинку в будинку з двома британськими солдатами в кімнаті є сценаОдну хвилину годинник каже 1,48 вечора, наступний, за його словами, 13,45 вечора, наступного ви навіть не можете побачити руки годинника, а потім наступної хвилини повернеться до 1,48 вечора.Або режисеру вдалося маніпулювати часом, або він/вона серйозно зіпсував безперервність.Моя ставка на останній.Моя порада - залишатися подалі від цього фільму, якщо ви справді не вписуєтесь на погані акторські, погані вмираючі та безперервні помилки.Саме через ці моменти зазначається, що я дав цей фільм 2 з 10 рейтингу, тому що їм вдалося змусити мене сміятися.',",
#  "'Як люди можуть слухати цей матеріал.Це просто прості катування.Ці люди - це не група, вони просто хочуть уваги та грошей.Вони не поважають мистецтва музики.Ці ідіоти не порівнюються з жодною хорошою рок -групою минулого.AC/DC, LED Zeppelin, Black Sabbath, Metallica ... Це справжні смуги, а не це виробництво сміття.Просто жахливо, що музика затонула це низько.І той факт, що цей марний фільм існує, - це лише ганьба.Дісней дійсно повинен почати пробувати, перш ніж вони втратить всю свою авторитет.Не бачите цього фільму і не слухайте цю групу, якщо ви робите частину проблеми, а не рішення повернути хорошу музику!',",
#  "В армії зараз підтвердили, що Полі Шор - один з найгірших акторів там.Він не найменше смішний і не розважає.Цей фільм є ідеальним прикладом Полі Шор у найгіршому. Крім того, що Полі Шор не має жодного таланту, в армії зараз був фільм, який слід забути.Сюжет був жорстоким, і будь -яка спроба комедії відчувала, що це образа мого інтелекту.Весь фільм був нестерпним. Я не думаю, що я навіть пам’ятаю, як закінчив цей фільм, незважаючи на те, що дивився це 17 років тому.Я пам’ятаю лише невеликі частини фільму.Ось як запам'ятовується цей фільм. Не турбуйтеся з цією забутною комедією. 1/10.",
#  "'Що стосується шаленого сталкера/п’ятниці, 13 -й фільми типу на Хеллоуїн йдуть, я думаю, що це було ефективно.Кейн робить хорошим чудовиськом.Акторський склад невідомих, здається, намагається важко.Були кілька грубих гористих частин, деяка атмосфера ефекту, деякі несподівані способи вбиття, і для мене все-таки несподіванка в деяких поворотах.Це B-фільм, але в цьому контексті він працює для мене.Театр був повним, і натовп, здавалося, потрапив у нього.Якщо ви хочете подивитися фільм Маніяк проти групи підлітків, це добре побачити. Налаштування для лиходія є ефективним, і вони насправді зробили гарну роботу, пояснивши, як він створився так само зіпсовано, як і.Насправді до кінця фільму ви отримуєте достатньо спалахів, що, на вашу думку, він був закручений у форму, а не просто народженого зла Ала Фредді чи Джейсона.',",
#  "'Я в основному насолоджувався цим фільмом.Мені не потрібен фільм, щоб розважати багаторівневий сюжет та глибокі недоліки персонажів.Більшість тут все було добре.Актори добре справлялися зі сценарієм, який їм дали.Я не бачив нічого поганого з CGI, як прокоментували інші.Дія була чудовою, і майже все мало сенс. Я змінив лише дві речі.Історія одного героя не була повністю завершена в кінці.10 -секундна сцена виправила б цю частину закінчення. Іншим пунктом була мова.Я втомився від постійного використання слова F.Це безглузде словесне сміття і нічого не додає фільму.',",
#  "'Перервники всередині-це хороший фільм на дат-ніч, це кемпі-комедія жахів, яка відкидає вібрації північної експозиції.Вам сподобається Кенан Томпсон схожий на Сем Річардсон як новий парк-рейнджер у місті.(Сем також грав у комікси в нещодавно випущеному завтрашній війні Amazon.) І, звичайно, є Лілі AT&T Лілі Мілана Вайнтруб, яка грає милого Ditz, але дивує нас у закінченні фільму.Це низькобюджетне виробництво, але воно рухається по хорошому темпі, а закінчення настільки ж кемпі, як і решта, тому просто насолоджуйтесь легким жахливим.',",
#  "Поза всякими сумнівами «Відьма з Блер: Курсова з того світу» такого вже далекого 1999 року – фільм легенда, що встановив нові стандарти в жанрі хорор – стали актуальними терміни «мак'юментарі» та «фаундфутейдж/знайдена плівка», за слідами яких вийшло безліч стрічок різного змісту. І що ми бачимо сьогодні? На цій легенді через 17 років намагаються заробити. Тому доказ сіквел «Відьма з Блер: Нова глава». І начхати, що глядач уже не той, що не так просто сьогодні здивувати, що історія давно розказана! Ось він фільм – бійтеся! Пам'ятаючи приголомшливу силу минулої картини, ти, можливо, підеш дивитися, як і я. Раптом? І що ж я маю вам сказати за цей «новий» жах? Нову частину «Відьми» було знято за 32 дні у Ванкувері та Британській Колумбії – воно й видно. Хоча про все по порядку. Нашому головному герою Джеймсу (Джеймс Аллен МакКьюн) - молодшому брату Хезеру трапляється запис в Інтернеті, зроблений у тому самому будинку, де колись закінчилася зйомка Хезер, після якої вона зникла. Надихнувшись, Джеймс наважується вирушити на пошуки сестри (ага, сестра сидить там 20 років і чекає на нього, коли ж – коли ж милий братик прийде, господарство розвела). Він виходить на того, хто розмістив відео, збирає друзів і вирушає до магічного лісу. Режисер нової «Відьми з Блеєр» – Адам Вінгард безумовно зіткнувся з непростим завданням – залишитися в жанрі старого фільму мак'юментарі та привнести щось нове. Тільки от не дуже вийшло. Зовсім не дуже. Дорогою до лісу ми бачимо групу молодих людей, озброєних технікою біля наших днів. Тут тобі і міні-камери bluetooth (ви користуєтеся блютус?), GPS-навігатор, потужний canon, літаючий дрон, за допомогою якого вони, мабуть, хочуть зловити відьму в ступі. Чого Go Pro не взяли? Ось зараз прикро було за наше Go, за наше Pro. У сумі все це цифрове залізо як би не дає право глядачеві ставити запитання: «а як це герой лісом біжить, ми спостерігаємо за ним, а хто ж його знімає?». Не підкопатись – bluetooth камера все фіксує. Лади. Тільки це не рятує фільм жодного разу. Прийоми мак'юментарі, яких не уникнути за такої стилістики фільму, неабияк дратують. У другій частині екран перетворюється на перебивки, склеювання, трясучки, перешкоди та зависання. Додайте сюди звуки, що оглушують слонячі хоррор звуки, банальні скримери, при цьому живуть ніби окремо від того, що відбувається на екрані і жанру, мокументарі в цілому. Серйозно! Що зі звуковою доріжкою? Розумію, що намагалися врятувати фільм, як тільки можна, але це якийсь перебір за звуковими спецефектами. , таємниче зараження одного з героїв, заблукали, не ходіть у цей чортовий будинок (чому в нього завжди всі ходять? сиди вже і бійся тихо), лякаючі тіні, відбитки рук, дивні постаті тощо. Закінчується це найбільшим кліше - не дивись на відьму! Серйозно, просто не дивись! Єдиним оригінальним рішенням була сцена зі зламаним тотемом, яка є у трейлері. Свіжий. Хоч би весь цей хорор набір допомагав по-особливому розкрити історію цієї відьми, розширював міфологію лісу Блек Хіллз, ну, будь ласка. Чесно, я дуже цього чекала. Ні, також ні. Нічого нового нам не розповіли. Герої прийшли, намагалися втекти, не пішли.,",
#  "'Будучи жахом/темним фентезією, мені дуже хотілося сподобатися, і з оглядом, подібними до інших шоу, як переслідування Хілл Хаус, я дійсно думав, що буду.Але я цього не зробив.Акторська майстерність була середньою в кращому випадку, спецефекти були поганими, а найважливіший аспект, сюжетна лінія, був перекручений, невмілий і просто нудний.Я не зробив це за два з половиною епізоди. На плюс дизайн сцена була прекрасною разом з кінематографією, і партитура теж була пристойною - хоча це звучить так, ніби вона була натхненна скрипкою в набагато кращому підприємстві жахів перетягніть мене в пекло.'",
#  "Черговий перезапуск знаменитої франшизи – цього разу мова про «Трансформери» – вкотре довів, що вносити оригінальні сюжетні ходи та свіжий драйв, перебуваючи в рамках франшизи, під силу не кожному. Ще до зародження людства на такій собі планеті відбулася епічна мала місце епічна битва між Максималами та поплічниками вселенського зла під назвою Юнікрон. Вождь Максималов жертвує собою заради порятунку артефакту у вигляді ключа, що відкриває тунелі у часі та просторі. У результаті ключ виявляється на Землі. 1994, Нью-Йорк. Колишній військовослужбовець Ной (Ентоні Рамос), не зумівши влаштуватися на роботу, піддається на вмовляння свого приятеля і вирушає викрадати «Порше», який самотньо стоїть у якомусь підземному гаражі. Він - як вже здогадався прозорливий глядач - виявляється Трансформером на ім'я Міраж, який, перейнявшись раптовою симпатією до Ноя, знайомить його з рештою Трансформерів на чолі з Оптімусом Праймом. Юнікрон та його поплічники теж не сидять склавши руки і Ною з новими знайомими (у числі яких також варто згадати другого людського персонажа фільму – талановиту дослідницю артефактів Олену (Домінік Фішбек) доводиться вирушити до Перу, Міста Сонця, де зберігається друга частина ключа-артеак (Як же інакше). І, як водиться, мета всього заходу – порятунок світу (і не одного). Ось тільки сетап в черговий раз ріже око зайво знайомими рисами - розділений надвоє могутній артефакт, які спочатку не підозрюють люди, обов'язкова перемога світлих сил, що носить, втім, половинчастий характер - як же інакше продовжувати франшизу. Але цікаво, що автори натякнули в . створення команди на кшталт Мстителів, до якої мають увійти Трансформери та представники ще однієї популярної іграшкової франшизи головного натхненника всього заходу – компанії Hasbro.,",
#  "'Мій товариш отримав мені цей DVD на 22 -й день народження сьогодні.Ми бачили попередній перегляд в Інтернеті, і з тих пір він був легендарним.Зараз я насправді бачив фільм, я щасливий весь час.Серйозно.Мої батьки отримали мені дивовижний і фантастичний і дорогий годинник, але коли люди йдуть так що ти отримав?Я збираюся кричати Boa vs Python !!!На них, пришпите їх до кушетки для вітальні і змушуйте їх переглянути цей фільм а -ля -годинник помаранчевий.Тільки тоді людство справді знайде мир.Як людям не подобається цей фільм?Дубляж ідеальний, сценарій неперевершений, а зображення Адама Кендріка британського власника казино-великого гри Hunter на місці.Він навіть отримав дію полум\\'я просто правильно!Я знаю багато власників казино-великих мисливців, які бачили цей фільм, і всі вони кажуть, що він його отримав.Весь цей фільм схожий на те, що вони взяли документальний фільм про шаленого хробака і отримали кубик льоду, щоб сутенерувати його.СУМІНА МОЙ ДОКУМЕНТ ДОКУМЕНТ!Вони плакали.І вони це зробили.Ой, одна маленька річ ... Я добре очікував, що розлючений чорний хлопець буде частиною якоїсь команди SWAT ... О, почекай, вони також потрапили туди.Топ -речі.',",
#  "«Під Сільвер-Лейк» – напевно, найкращий фільм, який я бачив з часів «Поганих часів у готелі «Ель Рояль» та останнього опусу братів Коен. Але від Коенів очікуєш на щось видатне, а третій фільм Девіда Роберта Мітчелла, автора «It Follows» («Воно» здорової людини), міг виявитися чим завгодно. Він виявився енциклопедією нео-нуару сімдесятих-дев'яностих, насамперед – лос-анджелеського. Перше, що впадає у вічі – фільм зухвало неполіткоректний. У кадрі жодного чорношкірого актора, на наших очах вмирають дрібні тварини та б'ють дітей, здається, в одній сцені навіть знущаються з гея і так, якщо ми бачимо в кадрі одягнуту дівчину, то в рольовому одязі для сексуальних ігор. Що природно: нео-нуар – жанр сексистський (як у найкращих зразках жанру від Брайана де Пальми) та неполіткоректний, в його основі завжди лежать нігілізм, секс, насильство та обман, підміна. Підміна особистості, підміна реальності, підміна понять - мало який жанр зробив для викриття цинічності суспільства та громадських інститутів стільки ж. Цікаво, що Девід Роберт Мітчелл якраз відмовляється від соціального чи політичного коментаря. Поки серйозні режисери знімають серйозні фільми – про політиків, чорношкірих супергероїв або місячних космонавтів, Мітчелл ніби валяє дурня, вправляючись у чистому стилі. Він проводить вас по ляльковому пеклі задвірків Голлівуду, то маскуючись під Хічкока (і навіть у якийсь момент ткне всіх незрозумілих носом прямо в могилу Хіча), то під Пола Томаса Андерсона, якого дуже ріднить з Мітчеллом дуже висока візуальна культура та невиразні меседжі фільмів . З близькості з Андерсоном найхимернішим чином проростає сюжет, типовий для Томаса Пінчона (це такий американський гібрид Сорокіна з Пелевіним, а чи не єдиною екранізацією його текстів якраз став «Вроджена вада» ПТА). До речі, одним із пояснень фільму «Під Сільвер-Лейк» може стати ідея створення ідеальної екранізації Пінчона, в якій були б зібрані всі його типові персонажі та мотиви. Судіть самі: герой-шоломіль, зайнятий дивними пошуками. Низка різного роду, але неодмінно яскравих фриків, від божевільного художника коміксів до дивної рок-групи «Ісус і нареченої Дракули». Нарешті, розслідування кількох переплетених між собою змов, починаючи локальною історією, пов'язаною із зникненням мільйонера та підозрілим релігійним культом, аж до всесвітньої змови. Але ні, виявляється, Девід Роберт Мітчелл не читав Томаса Пінчона. І тоді виникає цілком закономірне питання: а заради чого вся ця пишність? Фільм чудовий, я сам подивився його двічі, але що ж, пробач Господи, хотів сказати автор? «Під Сільвер-Лейк» – це фільм-трикстер, насмішник і ошуканець, готовий повернутися до вас будь-якою стороною свого інтелекту, що виблискує яскравими вогнями ерудиції, але зовсім позбавленого відповідальності (як власне, головний герой у виконанні Ендрю Гарфілда, якого виселяють з квартири за несплату, доки він розслідує всесвітню змову). Наприклад, прекрасна ідея цієї самої всесвітньої змови навколо артефактів поп-культури, в яких зашифровані різного роду послання – крім смішного воза, це ще й уїдлива пародія на критику, дякую, містер Мітчелл. Цілком можливо, що Сем, струсивши у фіналі наслання, напише про це сценарій чи роман. А ще «Під Сільвер-Лейк» можна розглядати як найхимернішу історію порятунку від любовної мани, а хочете – як метафору краху надій у Голлівуді: тим цей фільм і прекрасний, що кожен глядач може збирати його самостійно, як кубик Рубіка. Звичайно ж, ми все це вже проходили з Девідом Лінчем у тому ж «Малхолланд драйві», який, звичайно ж, Мітчелл цитує у своєму фільмі. Але весь фокус у тому, що крім Мітчелла нікому ще не вдавалося зробити такий трюк. Однозначно одне: цей фільм запам'ятають надовго і ще не раз згадуватимуть. А ще поспішіть побачити «Під Сільвер-Лейк», поки він у кінотеатральному прокаті. Я неодмінно піду ще раз переглянути.,",
#  "Проста та життєва історія собаки в сім'ї. Сюжет починається з того, що молода сім'я вирішує завести собаку. У результаті собака виявляється не найслухнянішою, і спочатку здається що фільм швидше комедійний, так як сім'я потрапляє в безліч кумедних ситуацій з собакою) але далі події фільму вже були швидше просто життєвими, ніж веселими. А життя – це не завжди білі, а й чорні смуги. Незважаючи на те, що фільм досить передбачуваний, він змушує задуматися про вічні та найважливіші цінності. У гонитві за грошима ми часто забуваємо заради чого взагалі варто жити) Собака - це зразок відданості та безоплатного кохання. Дивилася із завмиранням серця від початку і до кінця. В кінці наверталися сльози звичайно ж, але це життя. Після перегляду фільму захотілося завести собаку такої породи, вона там просто чудова. Фільм вчить відповідальності, співчуття, милосердя. Своїм дітям я обов'язково покажу цей фільм. І обов'язково заведу собаку. Оскільки незважаючи на те, що одного разу з одним доведеться розлучатися, ті роки радості та щастя які ми подаруємо один одному за час спільного життя того варті. На мою думку, фільм на 9/10, рекомендую!,",
#  "'На мою думку, цей фільм був абсолютно приголомшливим!Від танцю до акторської майстерності до музики!Це було чудово!З оглядів, які я читав, більшість людей ненавидять на ньому, що дурно !!Всі ролі були чудовими, а хореографія - приголомшливою.Я не розумію, що було так погано в цьому фільмі, звичайно, це не було схоже на крок вгору, але це не робить його жахливим фільмом.Кріс Браун теж не був жахливим.Перестаньте ненавидіти кожну дрібницю, тому що це не було розчарування, як деякі з вас, хлопці, говорять.(можливо, хтось інший - це розчарування) Це не було марнотратством мого часу, а також не було моїх грошей.Тож хлопці дивляться фільм для себе і не йдуть на те, що думають інші, бо це неправда!Чудовий фільм B- Boying весь шлях!'"]

# %%
len(samples)
# Out:
# 15

# %%
reviews = []
l_s = len(samples)
for i in range(l_s):
    if i <= l_s / 3:
        sent = "Негативний"
    elif i > l_s / 3 and i <= l_s / 3 * 2:
        sent = "Нейтральний"
    else: 
        sent = "Позитивний"
    reviews.append({"title": samples[i][:30]+'...', "content":samples[i], "sentiment":sent})

# %%
import tkinter as tk
from tkinter import Frame, Label, Button, Toplevel, messagebox
import joblib

# Load the model and vectorizer
model = joblib.load("models/linear_svc.joblib")
vectorizer = joblib.load("models/vectorizer.joblib")

# Sentiment color mapping
sentiment_colors = {
    "Позитивний": "#4CAF50",  # Green
    "Нейтральний": "#FFC107",  # Amber
    "Негативний": "#F44336",  # Red
}

def analyze_text():
    """Analyze the sentiment of the input text."""
    text = text_input.get("1.0", "end-1c").strip()
    if not text:
        tk.messagebox.showwarning("Input Error", "Please enter some text for analysis.")
        return
    text_vectorized = vectorizer.transform([preprocess(text)])
    sentiment = model.predict(text_vectorized)[0]
    sentiment_map = {0: "Негативний", 1: "Нейтральний", 2: "Позитивний"}
    result_label.config(text=f"Настрій: {sentiment_map[sentiment]}")

def clear_text():
    """Clear the input text and result label."""
    text_input.delete("1.0", "end")
    result_label.config(text="")

def load_review():
    """Open the Load Review window and manage review selection."""
    def populate_review_list():
        """Populate the list with reviews."""
        for widget in review_list_frame.winfo_children():
            widget.destroy()  # Clear previous entries

        for idx, review in enumerate(reviews):
            # Create a frame for each review
            item_frame = Frame(review_list_frame, bg="white", padx=10, pady=5, relief="ridge", bd=1)
            item_frame.pack(fill="x", pady=5)

            def select_review(event, i=idx, frame=item_frame):
                """Handle review selection and styling."""
                nonlocal selected_review_idx
                if selected_review_idx != -1:  # Deselect the previous frame
                    previous_frame = review_list_frame.winfo_children()[selected_review_idx]
                    previous_frame.configure(bg="white")
                # Update the new selection
                selected_review_idx = i
                frame.configure(bg="#FFC0CB")  # Highlight the selected frame

            # Bind click event to select review
            item_frame.bind("<Button-1>", select_review)

            # Title
            title_label = Label(item_frame, text=review["title"], font=("Arial", 12, "bold"), bg="white", anchor="w")
            title_label.pack(side="left", expand=True, fill="x", padx=5)
            title_label.bind("<Button-1>", select_review)

            # Sentiment
            sentiment_label = Label(
                item_frame,
                text=review["sentiment"],
                font=("Arial", 12, "bold"),
                bg=sentiment_colors[review["sentiment"]],
                fg="white",
                padx=10,
                pady=5,
                relief="solid"
            )
            sentiment_label.pack(side="right", padx=5)
            sentiment_label.bind("<Button-1>", select_review)

    def load_selected_review():
        """Transfer selected review to the main window text field.""" 
        if selected_review_idx == -1:
            tk.messagebox.showwarning("Selection Error", "Please select a review to load.")
            return
        text_input.delete("1.0", "end")
        text_input.insert("1.0", reviews[selected_review_idx]["content"])
        review_window.destroy()

    def resize_canvas(event):
        """Adjust the canvas width to match the container frame."""
        canvas_width = event.width
        canvas.itemconfig(scrollable_window, width=canvas_width)

    # Initialize variables
    selected_review_idx = -1

    # Create the Load Window
    review_window = Toplevel(window)
    review_window.title("Приклади рев'ю")
    review_window.geometry("600x500")
    review_window.configure(bg="#f5f5f5")
    review_window.resizable(False, False)

    # Title
    title_label = Label(
        review_window, text="Оберіть рев'ю", font=("Arial", 14, "bold"), bg="#f5f5f5", fg="#333"
    )
    title_label.pack(pady=10)

    # Create a frame with scrollbar for reviews
    container_frame = Frame(review_window, bg="#f5f5f5")
    container_frame.pack(fill="both", expand=True, padx=10, pady=10)

    canvas = tk.Canvas(container_frame, bg="#f5f5f5", highlightthickness=0)
    scrollbar = tk.Scrollbar(container_frame, orient="vertical", command=canvas.yview)
    scrollable_frame = Frame(canvas, bg="#f5f5f5", padx=10)

    scrollable_window = canvas.create_window((0, 0), window=scrollable_frame, anchor="nw")

    # Bind resize event to dynamically adjust canvas width
    container_frame.bind("<Configure>", resize_canvas)

    scrollable_frame.bind(
        "<Configure>",
        lambda e: canvas.configure(scrollregion=canvas.bbox("all"))
    )

    canvas.configure(yscrollcommand=scrollbar.set)

    canvas.pack(side="left", fill="both", expand=True)
    scrollbar.pack(side="right", fill="y")

    review_list_frame = scrollable_frame

    # Populate initial reviews
    populate_review_list()

    # Load Button
    load_button = Button(
        review_window,
        text="Завантажити обране рев'ю",
        command=load_selected_review,
        font=("Arial", 12, "bold"),
        bg="#4CAF50",
        fg="white",
        activebackground="#45a049",
        relief="flat",
        padx=10,
        pady=5
    )
    load_button.pack(pady=10)

# Main Window Setup
window = tk.Tk()
window.title("Модуль сентиментального аналізу тексту")
window.geometry("550x520")
window.configure(bg="#f5f5f5")

# Title label
title_label = Label(window, text="Модуль сентиментального аналізу тексту", font=("Arial", 18, "bold"), bg="#f5f5f5", fg="#333")
title_label.pack(pady=10)

# Instruction label
instruction_label = Label(window, text="Введіть ваше рев'ю нижче:", font=("Arial", 12), bg="#f5f5f5", fg="#555")
instruction_label.pack()

# Text input field
text_input = tk.Text(window, height=14, width=50, font=("Arial", 12), bd=2, relief="solid", padx=10, pady=10)
text_input.pack(pady=10)

# Button row
button_frame = Frame(window, bg="#f5f5f5")
button_frame.pack(pady=10)


# Load Review button
load_button = Button(
    button_frame,
    text="Завантажити",
    command=load_review,
    font=("Arial", 12, "bold"),
    bg="#2196F3",
    fg="white",
    activebackground="#1E88E5",
    relief="flat",
    padx=10,
    pady=5
)
load_button.pack(side="left", padx=5)

# Analyze button
analyze_button = Button(
    button_frame,
    text="Аналізувати",
    command=analyze_text,
    font=("Arial", 12, "bold"),
    bg="#4CAF50",
    fg="white",
    activebackground="#45a049",
    relief="flat",
    padx=10,
    pady=5
)
analyze_button.pack(side="left", padx=5)

# Clear button
clear_button = Button(
    button_frame,
    text="Очистити",
    command=clear_text,
    font=("Arial", 12, "bold"),
    bg="#F44336",
    fg="white",
    activebackground="#E53935",
    relief="flat",
    padx=10,
    pady=5
)
clear_button.pack(side="left", padx=5)

# Result label
result_label = Label(window, text="", font=("Arial", 16, "bold"), bg="#f5f5f5", fg="#333", wraplength=450, justify="center")
result_label.pack(pady=12)

# Footer label
footer_label = Label(window, text="Зроблено Пархоменко Едуардом, всі права захищені", font=("Arial", 10, "italic"), bg="#f5f5f5", fg="#888")
footer_label.pack(side="bottom", pady=5)

# Run the application
window.mainloop()
